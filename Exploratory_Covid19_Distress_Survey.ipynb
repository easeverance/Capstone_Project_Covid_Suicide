# %%
# Cite:
# OBrien, William, 2020, "Time1 dataset (october 26, 2020): demographic, health, and psychological predictors (mindfulness, perceived susceptibility) of COVID-19 PPE use, social distancing, psychological distress, and physical symptoms", https://doi.org/10.7910/DVN/UDHBOB, Harvard Dataverse, V1, UNF:6:NByE2zYH4xRsgUbD8vqE0A== [fileUNF]

# %%
import pandas as pd
import numpy as np

# %%
# Harvard Dataverse (Time 1 first data set (1 of 2)) 
# Survey Team - William O'Brien
data = pd.read_excel("time1dataset.xlsx")

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      ID_case#                Date  Gender   Age                    Occupation  \
# 0           1 2020-04-09 12:15:43       2  24.0               Account Officer
# 1           2 2020-04-09 12:21:26       2  41.0  Customer Care Representative
# 2           3 2020-04-09 12:36:29       2  35.0              IT Administrator
# 3           4 2020-04-09 12:38:05       1  35.0                      Mahnager
# 4           5 2020-04-09 12:43:36       1  47.0              research analyst
# ..        ...                 ...     ...   ...                           ...
# 445       548 2020-04-18 14:06:48       1  29.0                            IT
# 446       549 2020-04-18 14:10:47       2  26.0                      engineer
# 447       551 2020-04-18 15:00:24       2  45.0                     Marketing
# 448       553 2020-04-18 15:20:40       1  28.0                     marketing
# 449       634 2020-04-24 03:42:26       2  25.0            software developer
#
# ...

# %%
df.isnull().sum()
# Out:
# ID_case#                                                     0
# Date                                                         0
# Gender                                                       0
# Age                                                          1
# Occupation                                                   1
# Employment_status_Befor_COVID                                0
# Employment_status_After_COVID                                0
# Marital_status                                               0
# Education                                                    0
# Race                                                         0
# Religion_Protestant                                        366
# Religion_Roman_Catholic                                    207
# Religion_Mormon                                            448
# Religion_Jewish                                            435
# Religion_Muslim                                            440
# ...
